# %%
from eval import *
np.random.seed(1)

# %%
# mean is 10
diff_dist(dist_type='uni_fix_c', dist_hyperpara_list=[1, 2, 3, 4, 5], input_file=None)
# Out:
# density 1 type_number 20 dist_type uni_fix_c dist_hyperpara 1 gamma 1 testnum 5 save 0 algo_list ['OFF', 'GRD', 'BAT', 'RCP', 'SAM1', 'SAM+', 'COL1', 'COL+']
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# optimal batch size 10
# OFF 1537.9595375100907 1.0
# GRD 652.9923303673435 0.4245835566158769
# BAT 1281.8477616535051 0.8334730078326881
# RCP 625.4516719556301 0.40667628549462176
# SAM1 951.480940896111 0.6186644821856168
# SAM+ 1189.138555563061 0.7731923542593583
# COL1 925.7638608664822 0.601942923911552
# COL+ 1097.3468465873157 0.7135082684710201
# {'OFF': 0.0, 'GRD': 5.551115123125783e-17, 'BAT': 0.01551292242315999, 'RCP': 0.001325908325082925, 'SAM1': 0.0, 'SAM+': 0.022903893522713967, 'COL1': 0.0, 'COL+': 0.020606821820149286}
# run time
# OFF 0.28321027755737305
# GRD 0.0006799697875976562
# BAT 0.6436386585235596
# RCP 0.016708755493164064
# SAM1 0.011669588088989259
# SAM+ 0.10715603828430176
# COL1 0.010607290267944335
# COL+ 0.11532378196716309
# ...
