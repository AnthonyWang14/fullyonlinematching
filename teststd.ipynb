# %%
from eval import *
np.random.seed(1)

# %%
diff_std(dist_type='uni_fix_b', dist_hyperpara=10, SYN=True)
diff_std(dist_type='geo_new', dist_hyperpara=10, SYN=True)
diff_std(dist_type='poisson', dist_hyperpara=10, SYN=True)
# Out:
# density 1 type_number 20 dist_type uni_fix_b dist_hyperpara 10 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'BAT', 'SAM+', 'COL+']
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# optimal batch size 2
# OFF 302.18277410868217 1.0
# RCP 118.0525925926288 0.3906661885040818
# GRD 231.09345015634958 0.7647472654190248
# BAT 224.76268517571458 0.7437971467390033
# SAM+ 208.0608962126728 0.688526660152515
# COL+ 197.83636532818997 0.6546910753325625
# {'OFF': 0.0, 'RCP': 0.009900838963942568, 'GRD': 0.0, 'BAT': 0.020564204347769656, 'SAM+': 0.0185467310101303, 'COL+': 0.011350257476771231}
# run time
# OFF 0.07911033630371093
# RCP 0.018300771713256836
# GRD 0.0005798816680908203
# BAT 0.4080955982208252
# SAM+ 0.10302438735961914
# COL+ 0.09403061866760254
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# optimal batch size 2
# OFF 308.74082987685193 1.0
# RCP 117.4347829843712 0.3803668696207516
# GRD 222.41084016165001 0.7203803923516157
# ...

# %%
diff_std(dist_type='geo_new', dist_hyperpara=10, SYN=True)
diff_std(dist_type='poisson', dist_hyperpara=10, SYN=True)
# Out:
# density 1 type_number 20 dist_type geo_new dist_hyperpara 10 gamma 1 testnum 3 save 0 algo_list ['OFF', 'RCP', 'GRD', 'BAT', 'SAM1', 'STH', 'COL1', 'CTH']
# max quit time 43
# max quit time 53
# max quit time 61
# optimal batch size 2
# optimal threshold for STH 0.1
# optimal threshold for CTH 0.1
# OFF 545.414500239629 1.0
# RCP 173.20932200246344 0.31757373873698547
# GRD 299.64661245994824 0.5493924571647764
# BAT 299.64661245994824 0.5493924571647764
# SAM1 318.7907833029446 0.5844926806362559
# STH 367.0609414993126 0.6729944681302819
# COL1 314.21439873744316 0.5761020262559804
# CTH 347.18800901770663 0.6365580835587775
# {'OFF': np.float64(0.0), 'RCP': np.float64(0.03451656182691932), 'GRD': np.float64(0.013349422632649943), 'BAT': np.float64(0.013349422632649943), 'SAM1': np.float64(0.01329208001807662), 'STH': np.float64(0.017801713038481663), 'COL1': np.float64(0.009387332630844125), 'CTH': np.float64(0.0023116931105901894)}
# max quit time 46
# max quit time 38
# ...
