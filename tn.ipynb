# %%
from eval import *
np.random.seed(1)
# 5*5

# %%
test_tn(dist_type='geo_new', dist_hyperpara=10, SYN=True)
# Out:
# density 1 type_number 5 dist_type geo_new dist_hyperpara 10 gamma 1 testnum 3 save 0 algo_list ['OFF', 'RCP', 'GRD', 'BAT', 'SAM1', 'STH', 'COL1', 'CTH']
# std of weights 0.8503138543276786
# density 1.0
# std of weights 0.8503138543276786
# density 1.0
# std of weights 0.8503138543276786
# density 1.0
# max quit time 55
# col_counts 0 0
# max quit time 35
# col_counts 0 0
# max quit time 25
# col_counts 0 0
# optimal batch size 2
# optimal threshold for STH 0.2
# multiset_ratio_of_optimal_threshold 0.11466666666666665
# optimal threshold for CTH 0.1
# OFF 1782.6901935754995 1.0
# RCP 270.2479789130528 0.151595594056095
# GRD 1199.704113581263 0.6729739793850803
# BAT 1199.704113581263 0.6729739793850803
# SAM1 1046.6685891267282 0.5871287074438042
# STH 1516.6710087031543 0.8507765478090185
# COL1 1019.6133089007095 0.571952048973633
# CTH 1456.4418204891772 0.8169909868455754
# ...

# %%
test_tn(dist_type='uniform', dist_hyperpara=10, SYN=True)
test_tn(dist_type='poisson', dist_hyperpara=10, SYN=True)
# Out:
# density 1 type_number 5 dist_type uniform dist_hyperpara 10 gamma 1 testnum 3 save 0 algo_list ['OFF', 'RCP', 'GRD', 'BAT', 'SAM1', 'STH', 'COL1', 'CTH']
# std of weights 0.8503138543276786
# density 1.0
# std of weights 0.8503138543276786
# density 1.0
# std of weights 0.8503138543276786
# density 1.0
# max quit time 14
# col_counts 1 1
# max quit time 14
# col_counts 1 1
# max quit time 14
# col_counts 1 1
# optimal batch size 4
# optimal threshold for STH 0.2
# multiset_ratio_of_optimal_threshold 0.4073333333333333
# optimal threshold for CTH 0.4
# OFF 1406.385302541198 1.0
# RCP 264.3000941367397 0.1879286520267069
# GRD 942.4807033327737 0.6701440221465662
# BAT 786.0852560136949 0.5589401813239354
# SAM1 773.410152716136 0.5499276416773278
# STH 1104.5109030916926 0.7853544125467975
# COL1 825.5711260899867 0.5870163209173631
# CTH 873.7050577104943 0.6212416015239896
# ...

# %%
# Out:
# density 1 type_number 5 dist_type geo_new dist_hyperpara 10 gamma 1 testnum 3 save 0 algo_list ['OFF', 'RCP', 'GRD', 'BAT', 'SAM1', 'COL1']
# max quit time 55
# max quit time 35
# max quit time 25
# max_bsize 20
# max_bsize 20
# optimal batch size 2
# OFF 3431.256038535685 1.0
# RCP 515.3448383255119 0.15019130969469688
# GRD 2291.3068866479475 0.6677749666346031
# BAT 2291.3068866479475 0.6677749666346031
# SAM1 2018.8823001243952 0.5883799627456449
# COL1 1966.964941214983 0.5732492472506949
# {'OFF': np.float64(0.0), 'RCP': np.float64(0.012571458563148475), 'GRD': np.float64(0.040816637020141204), 'BAT': np.float64(0.040816637020141204), 'SAM1': np.float64(0.029605373019737025), 'COL1': np.float64(0.005653497304118121)}
# max quit time 24
# max quit time 31
# max quit time 39
# max_bsize 20
# max_bsize 20
# optimal batch size 2
# OFF 3441.346029278376 1.0
# RCP 593.3532034189872 0.17241893095632954
# GRD 2322.5576852140834 0.6748980385739083
# ...

# %%
test_tn(dist_type='geometric', dist_hyperpara=0.5, SYN=True)
test_tn(dist_type='single', dist_hyperpara=20, SYN=True)
test_tn(dist_type='poisson', dist_hyperpara=20, SYN=True)
# Out:
# density 2.5 type_number 5 dist_type geometric dist_hyperpara 0.5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# rmin 0
# rmin 0
# rmin 0
# rmin 0
# rmin 0
# max quit time 12
# max quit time 12
# max quit time 12
# max quit time 12
# max quit time 12
# OFF 168.95151294999673 1.0
# RCP 61.8343157977773 0.36598852959711536
# GRD 109.43612360773113 0.6477368666128495
# SAM1 129.3089853357912 0.7653615115838694
# SAMC1 123.1996289946261 0.7292010994366682
# BAT 112.14995575217559 0.6637996534861913
# max quit time 27
# max quit time 27
# max quit time 27
# max quit time 27
# max quit time 27
# OFF 187.11100236614115 1.0
# RCP 82.13781200451797 0.4389790603750263
# GRD 171.8458258538947 0.9184164676624661
# SAM1 113.18961075661403 0.6049329506296117
# SAMC1 108.70785295466897 0.5809805494064324
# BAT 172.1157537456597 0.9198590759984356
# max quit time 16
# max quit time 16
# max quit time 16
# max quit time 16
# max quit time 16
# ...

# %%
test_tn(dist_type='geometric', dist_hyperpara=0.5, SYN=True)
test_tn(dist_type='single', dist_hyperpara=20, SYN=True)
test_tn(dist_type='poisson', dist_hyperpara=20, SYN=True)
# Out:
# density 2.5 type_number 5 dist_type geometric dist_hyperpara 0.5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# rmin 0
# rmin 0
# rmin 0
# rmin 0
# rmin 0
# max quit time 15
# max quit time 15
# max quit time 15
# max quit time 15
# max quit time 15
# OFF 170.2875179606136 1.0
# RCP 66.4982594113008 0.39050577639331974
# GRD 141.78397308437704 0.8326151839101369
# SAM1 99.80051771991864 0.5860706581148353
# SAMC1 104.59367049253198 0.6142180692111786
# BAT 141.27918153890838 0.8296508354275581
# max quit time 17
# max quit time 17
# max quit time 17
# max quit time 17
# max quit time 17
# OFF 90.09429913199392 1.0
# RCP 33.737718880379404 0.3744711841417567
# GRD 76.78244977264993 0.8522453752612995
# SAM1 50.276781678818594 0.5580462045124508
# SAMC1 50.38160041668667 0.5592096381467422
# BAT 76.87639028340836 0.8532880662158159
# max quit time 14
# max quit time 14
# max quit time 14
# max quit time 14
# max quit time 14
# ...
