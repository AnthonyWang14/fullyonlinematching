# %%
from eval import *
np.random.seed(1)

# %%
test_tn_nyc(dist_type='geo_new', dist_hyperpara=10, SYN=False)
test_tn_nyc(dist_type='uni_fix_b', dist_hyperpara=10, SYN=False)
test_tn_nyc(dist_type='poisson', dist_hyperpara=10, SYN=False)
# Out:
# density 1 type_number 20 dist_type geo_new dist_hyperpara 10 gamma 1 testnum 5 save 0 algo_list ['OFF', 'GRD', 'HG', 'BAT', 'RCP', 'SAM1', 'SAM+', 'COL1', 'COL+']
# test file nyc_10_1.3
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# optimal batch size 6
# OFF 6.748555449453649 1.0
# GRD 6.213463535732166 0.920710155272592
# HG 1.7861729330174334 0.26467485469976226
# BAT 3.3600426494992446 0.49789064854927845
# RCP 0.051385205593505824 0.00761425255795533
# SAM1 4.21052505150098 0.6239150115958307
# SAM+ 6.50792273554642 0.9643430782025048
# COL1 4.839752768292904 0.7171538864194591
# COL+ 6.537115078887121 0.9686687955444382
# {'OFF': 0.0, 'GRD': 0.0, 'HG': 0.0, 'BAT': 0.03876041889530692, 'RCP': 0.01522850511591066, 'SAM1': 0.0, 'SAM+': 0.10508696575366153, 'COL1': 0.0, 'COL+': 0.11318425437795046}
# run time
# OFF 0.08441181182861328
# GRD 0.0018973350524902344
# HG 0.21480245590209962
# BAT 0.3660422325134277
# RCP 0.005753946304321289
# ...

# %%
test_tn_nyc(dist_type='uniform', dist_hyperpara=10, SYN=False)
test_tn_nyc(dist_type='poisson', dist_hyperpara=10, SYN=False)
