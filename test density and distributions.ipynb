# %%
from eval import *
# 5*5

# %%
np.random.seed(1)

# %%
test_density(dist_type='geometric', dist_hyperpara=0.5, SYN=True)
# Out:
# density 1.0 type_number 50 dist_type geometric dist_hyperpara 0.5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 2
# 2
# 2
# 2
# 2
# OFF 64.74215160558695 1.0
# RCP 20.560276917195587 0.31757172734156286
# GRD 16.63332873631965 0.25691652692747813
# SAM1 64.70356791361846 0.9994040406286842
# SAMC1 64.70356791361846 0.9994040406286842
# BAT 21.624330014816106 0.33400697194237244
# density 1.5 type_number 50 dist_type geometric dist_hyperpara 0.5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 4
# 4
# 4
# 4
# 4
# OFF 108.146859412973 1.0
# RCP 16.50565358013071 0.15262258811512686
# GRD 33.84280707867185 0.3129337944936398
# SAM1 107.84900824800827 0.9972458639429617
# SAMC1 107.83026946083268 0.9970725922707439
# BAT 44.630050499547906 0.41268004213716636
# density 2.0 type_number 50 dist_type geometric dist_hyperpara 0.5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 3
# 3

# %%
test_density(dist_type='single', dist_hyperpara=20, SYN=True)
# Out:
# density 1.0 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 12
# 12
# 12
# 12
# 12
# OFF 161.76900940421302 1.0
# RCP 25.454977512360824 0.15735385662624876
# GRD 19.472399414000357 0.12037163042362815
# SAM1 147.0249622737312 0.908857406095374
# SAMC1 150.97302486708125 0.9332629619425078
# BAT 77.41481997519942 0.47855161047418315
# density 1.5 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 16
# 16
# 16
# 16
# 16
# OFF 231.15276538065692 1.0
# RCP 73.14365038027648 0.31642991707161816
# GRD 22.506819631127822 0.09736772819509264
# SAM1 182.29341854869534 0.7886274613608834
# SAMC1 187.04924796929106 0.8092018612075126
# BAT 102.65589172351585 0.44410410385731075
# density 2.0 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 13
# 13
# 13
# 13
# 13
# OFF 290.1063768575822 1.0
# RCP 101.70210842611534 0.3505683312712651
# GRD 32.27422702869072 0.11124962980229368
# SAM1 223.14904675493707 0.7691973171085601
# SAMC1 220.59967843562913 0.7604096153457702
# BAT 156.59807897130617 0.5397953697797641
# density 2.5 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 10
# 10
# 10
# 10
# 10
# OFF 313.81001256067566 1.0
# RCP 119.0674370632557 0.37942523277594215
# GRD 54.40370613796197 0.1733651061482397
# SAM1 227.26536005610296 0.7242132212469188
# SAMC1 232.09573431170253 0.7396058921696339
# BAT 158.22926849882577 0.5042199489037397
# density 3.0 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 11
# 11
# 11
# 11
# 11
# OFF 347.19738004068967 1.0
# RCP 154.67125668735451 0.4454850917055534
# GRD 62.422928481161065 0.1797908972522933
# SAM1 242.96215982407793 0.6997810864690398
# SAMC1 241.429552740641 0.6953668622509385
# BAT 177.11311745023502 0.5101222752011502
# density 3.5 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 8
# 8
# 8
# 8
# 8
# OFF 391.67602768093536 1.0
# RCP 163.56998073463595 0.41761550152332094
# GRD 71.17982648857101 0.18173138374083764
# SAM1 241.75696098256458 0.6172370630236862
# SAMC1 234.46935263609345 0.5986308481128066
# BAT 218.97249567477357 0.5590653504409812
# density 4.0 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 9
# 9
# 9
# 9
# 9
# OFF 424.710387618073 1.0
# RCP 194.84726933666104 0.4587767924147885
# GRD 93.03538537185555 0.21905606287058602
# SAM1 245.37661645601193 0.5777504473864444
# SAMC1 238.93440429491102 0.5625819647005579
# BAT 254.62762887644743 0.599532378533263
# density 4.5 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 12
# 12
# 12
# 12
# 12
# OFF 385.73718479278546 1.0
# RCP 156.4477547754479 0.40558121162078326
# GRD 86.38766751379363 0.22395473114732328
# SAM1 247.0807543984356 0.6405417059575554
# SAMC1 250.34939575830762 0.6490154582654328
# BAT 184.7744265301619 0.47901637128767105
# density 5.0 type_number 50 dist_type single dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 8
# 8
# 8
# 8
# 8
# OFF 427.81872020092686 1.0
# RCP 205.71340354356434 0.4808424545960733
# GRD 96.35533600522245 0.2252246838566783
# SAM1 242.56689008870794 0.5669852174182218
# SAMC1 248.36749087506422 0.5805437657296001
# BAT 258.84078240701325 0.6050244418604394

# %%
test_density(dist_type='poisson', dist_hyperpara=20, SYN=True)
# Out:
# density 1.0 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 13
# 13
# 13
# 13
# 13
# OFF 191.77531863924207 1.0
# RCP 46.08794848295984 0.24032262759348158
# GRD 15.695937469900358 0.0818454511314188
# SAM1 156.27078254881022 0.8148638920672521
# SAMC1 158.25606373761283 0.8252160124698635
# BAT 89.21389427461769 0.4652000836585354
# density 1.5 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 14
# 14
# 14
# 14
# 14
# OFF 216.5311257672131 1.0
# RCP 51.30566757141672 0.2369436144093856
# GRD 32.040402820652666 0.14797134918652968
# SAM1 185.25917905543716 0.8555775914387681
# SAMC1 191.15705050931376 0.88281557596861
# BAT 97.9081920923965 0.45216682703462696
# density 2.0 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 8
# 8
# 8
# 8
# 8
# OFF 291.6415760694606 1.0
# RCP 94.7626110716429 0.32492833274592225
# GRD 35.56477368292027 0.12194685737965484
# SAM1 228.0591194657447 0.7819842511460972
# SAMC1 233.97047967790178 0.8022535155350304
# BAT 128.97476906380652 0.4422372516361949
# density 2.5 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 10
# 10
# 10
# 10
# 10
# OFF 303.50894108035436 1.0
# RCP 109.70442887558718 0.36145369716321735
# GRD 55.25544565681177 0.18205541312927195
# SAM1 218.26591325228569 0.7191416255328686
# SAMC1 216.49623455002387 0.7133108954859627
# BAT 163.465804489613 0.538586454513494
# density 3.0 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 10
# 10
# 10
# 10
# 10
# OFF 364.1436226007216 1.0
# RCP 154.21763175990733 0.4235077101130639
# GRD 64.6867038643204 0.17764063366626218
# SAM1 235.58238588707155 0.6469490916922754
# SAMC1 243.65338654375864 0.6691134250919484
# BAT 193.7589667789759 0.5320949063865108
# density 3.5 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 9
# 9
# 9
# 9
# 9
# OFF 348.4906533728142 1.0
# RCP 141.64672514406394 0.4064577450590352
# GRD 52.286118495737114 0.15003592776361088
# SAM1 241.17043680238538 0.6920427692055833
# SAMC1 238.4378913369645 0.6842016823960108
# BAT 171.67971815614183 0.4926379416336294
# density 4.0 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 13
# 13
# 13
# 13
# 13
# OFF 368.1228940657349 1.0
# RCP 133.0480512426939 0.36142291986582015
# GRD 60.22443615610065 0.16359872511853746
# SAM1 251.8715552718192 0.6842050829548326
# SAMC1 249.9508617004489 0.6789875493476256
# BAT 174.23686951832133 0.4733116910876188
# density 4.5 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 11
# 11
# 11
# 11
# 11
# OFF 404.34148342240917 1.0
# RCP 151.11949677178802 0.37374225244634585
# GRD 69.51705491091145 0.17192659611007086
# SAM1 253.76376843383068 0.6275976590033124
# SAMC1 256.7647898802044 0.6350196564223569
# BAT 199.71599666885362 0.49392902993387267
# density 5.0 type_number 50 dist_type poisson dist_hyperpara 20 gamma 1 testnum 5 save 0 algo_list ['OFF', 'RCP', 'GRD', 'SAM1', 'SAMC1', 'BAT']
# 13
# 13
# 13
# 13
# 13
# OFF 384.04792373090385 1.0
# RCP 162.24240605803337 0.4224535429898952
# GRD 81.47612132900515 0.2121509225658362
# SAM1 250.5415118590504 0.6523704370671217
# SAMC1 250.3977424428527 0.6519960842655208
# BAT 202.3118449104195 0.5267880189144731
