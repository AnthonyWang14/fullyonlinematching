# %%
from eval import *
np.random.seed(2)

# %%
diff_dist_fix(dist_type='fix_single', dist_hyperpara_list=[5, 10, 15, 20], input_file=None)

# %%
diff_dist_fix(dist_type='fix_poisson', dist_hyperpara_list=[5, 10, 15, 20], input_file=None)
# Out:
# density 2.5 type_number 10 dist_type fix_poisson dist_hyperpara 5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'SAM1', 'SAMC1']
# max quit time 13
# max quit time 12
# max quit time 13
# max quit time 13
# max quit time 13
# OFF 195.14998602147588 1.0
# SAM1 112.15028081317273 0.5746876189928644
# SAMC1 112.15028081317273 0.5746876189928644
# {'OFF': 0.0, 'SAM1': 0.033766019641765656, 'SAMC1': 0.033766019641765656}
# max quit time 14
# max quit time 14
# max quit time 15
# max quit time 13
# max quit time 15
# OFF 187.77957695560394 1.0
# SAM1 106.50219378357883 0.567166011928756
# SAMC1 106.50219378357883 0.567166011928756
# {'OFF': 0.0, 'SAM1': 0.02497574391379883, 'SAMC1': 0.02497574391379883}
# max quit time 12
# max quit time 11
# max quit time 18
# max quit time 13
# max quit time 15
# OFF 201.40978760880958 1.0
# SAM1 115.99191605989722 0.5759000962017984
# SAMC1 115.99191605989722 0.5759000962017984
# {'OFF': 0.0, 'SAM1': 0.024522716776322392, 'SAMC1': 0.024522716776322392}
# ...

# %%
diff_dist_fix(dist_type='fix_geo', dist_hyperpara_list=[5, 10, 15, 20], input_file=None)
# Out:
# density 2.5 type_number 10 dist_type fix_geo dist_hyperpara 5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'SAM1', 'SAMC1']
# max quit time 30
# max quit time 29
# max quit time 25
# max quit time 30
# max quit time 27
# OFF 189.36328359897988 1.0
# SAM1 105.5561121797759 0.557426498810166
# SAMC1 105.5561121797759 0.557426498810166
# {'OFF': 0.0, 'SAM1': 0.017419316851975238, 'SAMC1': 0.017419316851975238}
# max quit time 31
# max quit time 27
# max quit time 25
# max quit time 24
# max quit time 30
# OFF 185.44873960095705 1.0
# SAM1 101.29380421043841 0.5462091811915213
# SAMC1 101.29380421043841 0.5462091811915213
# {'OFF': 0.0, 'SAM1': 0.015487358620128263, 'SAMC1': 0.015487358620128263}
# max quit time 28
# max quit time 36
# max quit time 42
# max quit time 32
# max quit time 26
# OFF 195.76561993304034 1.0
# SAM1 103.78437899881325 0.5301460952863514
# SAMC1 103.78437899881325 0.5301460952863514
# {'OFF': 0.0, 'SAM1': 0.02501794068759527, 'SAMC1': 0.02501794068759527}
# ...
