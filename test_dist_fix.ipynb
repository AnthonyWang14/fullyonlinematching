# %%
from eval import *
np.random.seed(2)

# %%
diff_dist_fix(dist_type='fix_single', dist_hyperpara_list=[5, 10, 15, 20, 25, 30, 35, 40], input_file=None)

# %%
diff_dist_fix(dist_type='fix_poisson', dist_hyperpara_list=[5, 10, 15, 20, 25, 30, 35, 40], input_file=None)

# %%
diff_dist_fix(dist_type='fix_geo', dist_hyperpara_list=[5, 10, 15, 20, 25, 30, 35, 40], input_file=None)
# Out:
# density 2.5 type_number 20 dist_type fix_geo dist_hyperpara 5 gamma 1 testnum 5 save 0 algo_list ['OFF', 'SAM1', 'SAMC1']
# max quit time 27
# max quit time 32
# max quit time 42
# max quit time 30
# max quit time 30
# OFF 168.21463052739435 1.0
# SAM1 109.46596864113435 0.6507517705084959
# SAMC1 110.38327273823529 0.6562049471687244
# {'OFF': 0.0, 'SAM1': 0.030640128542442312, 'SAMC1': 0.027619395448321652}
# max quit time 27
# max quit time 34
# max quit time 24
# max quit time 36
# max quit time 33
# OFF 186.58158935457777 1.0
# SAM1 110.236661366926 0.5908228231319937
# SAMC1 110.97175378796358 0.594762613888308
# {'OFF': 0.0, 'SAM1': 0.026491357244867886, 'SAMC1': 0.02784564597006264}
# max quit time 36
# max quit time 42
# max quit time 32
# max quit time 42
# max quit time 30
# OFF 187.11021168553395 1.0
# SAM1 112.04908576471014 0.5988400352676903
# SAMC1 111.76314409254992 0.5973118360871945
# {'OFF': 0.0, 'SAM1': 0.01873627838833933, 'SAMC1': 0.01640185620029774}
# ...
