# %%
from eval import *
np.random.seed(1)

# %%
diff_wf(dist_type='geo_new', dist_hyperpara=10, input_file=None)
diff_wf(dist_type='poisson', dist_hyperpara=10, input_file=None)
diff_wf(dist_type='uni_fix_b', dist_hyperpara=10, input_file=None)
# Out:
# density 1 type_number 20 dist_type geo_new dist_hyperpara 10 gamma 1 testnum 5 save 0 algo_list ['OFF', 'GRD', 'HG', 'BAT', 'RCP', 'SAM1', 'SAM+', 'COL1', 'COL+']
# test file nyc_20_1
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# optimal batch size 8
# OFF 4.748485042960969 1.0
# GRD 3.5858003817015387 0.7551461885758778
# HG 1.3722923991368674 0.2889958348233861
# BAT 1.9531542241623883 0.41132154918708097
# RCP 0.7694609660382554 0.16204346419472973
# SAM1 3.744485503389541 0.7885642409130611
# SAM+ 3.8241785677004474 0.8053470808272442
# COL1 3.6162064340130726 0.7615495050097385
# COL+ 3.8201726298109335 0.8045034564179282
# {'OFF': 0.0, 'GRD': 0.0, 'HG': 0.0, 'BAT': 0.04416592326333789, 'RCP': 0.03182407473555145, 'SAM1': 0.0, 'SAM+': 0.06745494522079215, 'COL1': 0.0, 'COL+': 0.07415308772958358}
# run time
# OFF 0.07702221870422363
# GRD 0.0019601821899414063
# HG 0.25127148628234863
# BAT 0.3348635196685791
# RCP 0.01605391502380371
# ...

# %%
diff_wf(dist_type='poisson', dist_hyperpara=10, input_file=None)
diff_wf(dist_type='uni_fix_b', dist_hyperpara=10, input_file=None)
# Out:
# density 1 type_number 20 dist_type poisson dist_hyperpara 10 gamma 1 testnum 5 save 0 algo_list ['OFF', 'GRD', 'HG', 'BAT', 'RCP', 'SAM1', 'SAM+', 'COL1', 'COL+']
# test file nyc_20_1
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# k_rcp 0.25
# optimal batch size 9
# OFF 4.1399601849889685 1.0
# GRD 3.1618508346388765 0.7637394306600805
# HG 0.4269670124822156 0.10313312046583203
# BAT 1.66741481797999 0.40276107582528187
# RCP 1.028779122186198 0.24849976236883525
# SAM1 3.1779083632294842 0.7676180980561658
# SAM+ 3.398530438373838 0.8209089668776354
# COL1 3.2020820065126188 0.7734571984829731
# COL+ 3.3789981559404354 0.8161909788872618
# {'OFF': 0.0, 'GRD': 0.0, 'HG': 0.0, 'BAT': 0.06340064705895551, 'RCP': 0.036007189917981644, 'SAM1': 0.0, 'SAM+': 0.07567604750345579, 'COL1': 0.0, 'COL+': 0.07698635593029379}
# run time
# OFF 0.061804342269897464
# GRD 0.0009796619415283203
# HG 0.2360518455505371
# BAT 0.3179012298583984
# RCP 0.015811777114868163
# ...

# %%
# L=20 delta = 5, A = 1, 2, 3, 4, 5
diff_wf(dist_type='geometric', dist_hyperpara=0.5, input_file=None)

# %%
diff_wf(dist_type='single', dist_hyperpara=20, input_file=None)

# %%
diff_wf(dist_type='poisson', dist_hyperpara=20, input_file=None)

# %%
diff_delta(dist_type='single', dist_hyperpara=20, input_file=None)

# %%
diff_delta(dist_type='poisson', dist_hyperpara=20, input_file=None)

# %%
diff_delta(dist_type='single', dist_hyperpara=20, input_file=None)

# %%
diff_delta(dist_type='poisson', dist_hyperpara=20, input_file=None)
